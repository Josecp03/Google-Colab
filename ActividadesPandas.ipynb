# %% [markdown]
# <a href="https://colab.research.google.com/github/Josecp03/Google-Colab/blob/main/ActividadesPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
fichero=pd.read_csv('/content/sample_data/democanarias.csv')
fichero
# Out:
#           Island  Population     Area Province
# 0   Gran Canaria      855521  1560.10     LPGC
# 1       Tenerife      928604  2034.38     SCTF
# 2       La Palma       83458   708.32     SCTF
# 3      Lanzarote      155812   845.94     LPGC
# 4      La Gomera       21678   369.76     SCTF
# 5      El Hierro       11147   278.71     SCTF
# 6  Fuerteventura      119732  1659.00     LPGC

# %%
fichero.loc[fichero['Island'].isin(['El Hierro', 'La Gomera'])]
# Out:
#       Island  Population    Area Province
# 4  La Gomera       21678  369.76     SCTF
# 5  El Hierro       11147  278.71     SCTF

# %%
fichero.loc[:, ['Island', 'Province']]
# Out:
#           Island Province
# 0   Gran Canaria     LPGC
# 1       Tenerife     SCTF
# 2       La Palma     SCTF
# 3      Lanzarote     LPGC
# 4      La Gomera     SCTF
# 5      El Hierro     SCTF
# 6  Fuerteventura     LPGC

# %%
fichero.iloc[[0, 2, 4, 6], [0, 2]]
# Out:
#           Island     Area
# 0   Gran Canaria  1560.10
# 2       La Palma   708.32
# 4      La Gomera   369.76
# 6  Fuerteventura  1659.00

# %%
fichero.loc[fichero['Area'] > 1000, ['Island', 'Population', 'Area', 'Province']]
# Out:
#           Island  Population     Area Province
# 0   Gran Canaria      855521  1560.10     LPGC
# 1       Tenerife      928604  2034.38     SCTF
# 6  Fuerteventura      119732  1659.00     LPGC

# %%
fichero['Ayuda'] = np.where(
    fichero['Area'] < 1000,
    fichero['Population'] * 0.30,
    fichero['Population'] * 0.20
)
fichero
# Out:
#           Island  Population     Area Province     Ayuda
# 0   Gran Canaria      855521  1560.10     LPGC  171104.2
# 1       Tenerife      928604  2034.38     SCTF  185720.8
# 2       La Palma       83458   708.32     SCTF   25037.4
# 3      Lanzarote      155812   845.94     LPGC   46743.6
# 4      La Gomera       21678   369.76     SCTF    6503.4
# 5      El Hierro       11147   278.71     SCTF    3344.1
# 6  Fuerteventura      119732  1659.00     LPGC   23946.4
